# %%
import os
import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
from time import sleep

from datetime import datetime

# %%
url_base = 'https://api.yelp.com/v3/'

url_review = 'businesses/{id}/reviews'
url_business = 'businesses/search'

# %%
apikey = 'Bearer CrgilvjOJW-U-DnMiyFz_xypRqtVtfL_yekfgb4Kg5xNRWe1A83s2llrJ7RxnXYa0iqT8GwTCHJZKvYMHL7CmV1zJPe0D1_jWrH8W0bMxTtR6Ufksbg5REDVrSDbY3Yx'

# %%
url = os.path.join(url_base, url_business)

# %%
api_header = {'Authorization': apikey, 'accept': 'application/json'}

# %%
def search_for_restaurant(term,location='San Francisco'):
    return

# %%
params = {
    'location': 'san francisco',
    'term': 'Soup',
    'limit': 50,
    'offset': 0
}

r = requests.get(url, headers=api_header, params=params)

# %%
# json.loads(r.text)
# Out:
# {'businesses': [{'id': '6-0FK0NyqLGkQVhQkUX14A',
#    'alias': 'the-soup-san-francisco-2',
#    'name': 'The Soup',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IVJZAx-r_QccMwpIiy6rlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-soup-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 44,
#    'categories': [{'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76319763236505, 'longitude': -122.4828244},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2315 Irving St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2315 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14154636099',
#    'display_phone': '(415) 463-6099',
#    'distance': 4084.8525168632464},
#   {'id': 'dJBtPz-oqRNfHZHz1h0tGA',
#    'alias': 'soupchu-san-francisco-2',
#    'name': 'Soupchu',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vQRp05-awwxHPLLeJpsi8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soupchu-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 14,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.79957734521015, 'longitude': -122.4172828},
#    'transactions': [],
#    'location': {'address1': '1096 Union St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1096 Union St', 'San Francisco, CA 94133']},
#    'phone': '+14152363986',
#    'display_phone': '(415) 236-3986',
#    'distance': 4618.817647826299},
#   {'id': 'nDGZ6Vjchclsv_0KWyA7NQ',
#    'alias': 'trad-bone-broth-san-francisco',
#    'name': 'Trad Bone Broth',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qGVfDWNo_rN8wuPLTXqXlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trad-bone-broth-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 50,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.75135, 'longitude': -122.42982},
#    'transactions': [],
#    'location': {'address1': '3903 24th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3903 24th St', 'San Francisco, CA 94114']},
#    'phone': '+16286880118',
#    'display_phone': '(628) 688-0118',
#    'distance': 1196.8674148834473},
#   {'id': 'OOlS_RmdMk1LHtgOQWoHoA',
#    'alias': 'tanglad-san-francisco',
#    'name': 'Tanglad',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jzNmvepv5zG5fbBOXfmtWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tanglad-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 234,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.761492, 'longitude': -122.434844},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '469 Castro St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['469 Castro St', 'San Francisco, CA 94114']},
#    'phone': '+14156243238',
#    'display_phone': '(415) 624-3238',
#    'distance': 159.10650212292109},
#   {'id': 'kvrQecqdGvnuVICMstZJmA',
#    'alias': 'dumpling-home-san-francisco',
#    'name': 'Dumpling Home',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Utdv29yFK-sfp9D1Tg-Bwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumpling-home-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 919,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.775830550017254, 'longitude': -122.4226361},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '298 Gough St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['298 Gough St', 'San Francisco, CA 94102']},
#    'phone': '+14155031666',
#    'display_phone': '(415) 503-1666',
#    'distance': 2056.7497118286074},
#   {'id': 'agUov63fwIufCj8t6pCivg',
#    'alias': 'leleka-san-francisco-4',
#    'name': 'Leleka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tmu4P8WjmDaL3rB-ujmaGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leleka-san-francisco-4?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 289,
#    'categories': [{'alias': 'ukrainian', 'title': 'Ukrainian'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.791322021300175,
#     'longitude': -122.40364911315856},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '40 Belden Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['40 Belden Pl', 'San Francisco, CA 94104']},
#    'phone': '+14159013434',
#    'display_phone': '(415) 901-3434',
#    'distance': 4444.434773866297},
#   {'id': '-ih1LY3Mn1-uc1yPjYpmMA',
#    'alias': 'thai-nghiep-ky-mi-gia-san-francisco',
#    'name': 'Thai Nghiep Ky Mi Gia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1BFOjtQfUNNk9n1c6ORu5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-nghiep-ky-mi-gia-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 564,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.753965, 'longitude': -122.479139},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1427 Noriega St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1427 Noriega St', 'San Francisco, CA 94122']},
#    'phone': '+14156828528',
#    'display_phone': '(415) 682-8528',
#    'distance': 3831.503745166982},
#   {'id': '3DNoAVehylJgUACvgXugJA',
#    'alias': 'rasa-rasa-san-francisco',
#    'name': 'Rasa Rasa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eJ0X9CGamERlt0pKuTR9NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rasa-rasa-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 104,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'indonesian', 'title': 'Indonesian'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7712452, 'longitude': -122.3911102},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1379 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94158',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1379 4th St', 'San Francisco, CA 94158']},
#    'phone': '+14157696389',
#    'display_phone': '(415) 769-6389',
#    'distance': 4207.4343114093435},
#   {'id': 'SxHKYiRVnMd9BnTEaEB-FA',
#    'alias': 'chic-n-time-san-francisco',
#    'name': "Chic n' Time",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2P3DQdjopiKsF21zE6LlyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chic-n-time-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 240,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.759907, 'longitude': -122.421268},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '807 Valencia St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['807 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14158749757',
#    'display_phone': '(415) 874-9757',
#    'distance': 1339.3019844458966},
#   {'id': 'GrVZzAPrdMji66PfJ0fRXg',
#    'alias': 'mr-hen-noodles-house-san-francisco',
#    'name': 'Mr. Hen Noodles House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4zg4HHK-898GnbqnDrXCoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-hen-noodles-house-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 20,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76085516290604, 'longitude': -122.4336963},
#    'transactions': [],
#    'location': {'address1': '4039 18th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4039 18th St', 'San Francisco, CA 94114']},
#    'phone': '+14159829598',
#    'display_phone': '(415) 982-9598',
#    'distance': 241.87018273717217},
#   {'id': 'AtFGQccBpgEZzsy9V1330Q',
#    'alias': 'lily-san-francisco',
#    'name': 'Lily',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y80_nZ_LfLw5AZip8L-MEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lily-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 349,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.782826, 'longitude': -122.461686},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '225 Clement St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['225 Clement St', 'San Francisco, CA 94118']},
#    'phone': '+14157425285',
#    'display_phone': '(415) 742-5285',
#    'distance': 3299.107317666393},
#   {'id': 'DgfhciOcB9X7SXFFQR7t9w',
#    'alias': 'blue-barn-gourmet-san-francisco-2',
#    'name': 'Blue Barn Gourmet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZjE9MSSQS4DPf-6oXPpoBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-barn-gourmet-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 593,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.797486, 'longitude': -122.422348},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2237 Polk St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2237 Polk St', 'San Francisco, CA 94109']},
#    'phone': '+14156559438',
#    'display_phone': '(415) 655-9438',
#    'distance': 4252.762808967805},
#   {'id': 'ltjuu-CHvGHUEyj-KtjPhA',
#    'alias': 'taishoken-san-francisco-san-francisco',
#    'name': 'Taishoken San Francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cJ77fHNibKZBp2SClfTukw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taishoken-san-francisco-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 187,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76223, 'longitude': -122.42134},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '665 Valencia St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['665 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14154005336',
#    'display_phone': '(415) 400-5336',
#    'distance': 1341.9518613445748},
#   {'id': 'q1Mv7oQSOorl4a9zbtl-rQ',
#    'alias': 'marugame-udon-san-francisco-4',
#    'name': 'Marugame Udon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r2oy9LzQkS3X7bQZDy9HDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marugame-udon-san-francisco-4?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 2304,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.727492017326746,
#     'longitude': -122.4764912099664},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3251 20th Ave',
#     'address2': 'Space 184',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94132',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3251 20th Ave',
#      'Space 184',
#      'San Francisco, CA 94132']},
#    'phone': '+14156801280',
#    'display_phone': '(415) 680-1280',
#    'distance': 5118.246080652685},
#   {'id': 'kKm6pi-NazSJArAyVNH7RA',
#    'alias': 'noodle-station-daly-city',
#    'name': 'Noodle Station',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H_oO_9PL9rz6dTgKIrrtrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-station-daly-city?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 281,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.70749, 'longitude': -122.45575},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6055 Mission St',
#     'address2': None,
#     'address3': '',
#     'city': 'Daly City',
#     'zip_code': '94014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6055 Mission St', 'Daly City, CA 94014']},
#    'phone': '+14153333888',
#    'display_phone': '(415) 333-3888',
#    'distance': 6172.120407989293},
#   {'id': 'uUifmxOmL8ClHXyRVsmD3Q',
#    'alias': 'bodega-san-francisco-3',
#    'name': 'Bodega',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CNR6OGg54OWzBTWrY9PMyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodega-san-francisco-3?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 354,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.784837858877935, 'longitude': -122.4093022},
#    'transactions': [],
#    'location': {'address1': '138 Mason St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['138 Mason St', 'San Francisco, CA 94102']},
#    'phone': '+14156559341',
#    'display_phone': '(415) 655-9341',
#    'distance': 3574.5895267450232},
#   {'id': 'AzFqspVE3gUWYaEselXLUA',
#    'alias': 'khob-khun-thai-cuisine-and-breakfast-san-francisco-2',
#    'name': 'Khob Khun Thai Cuisine & Breakfast',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MEvfDFIHwUNaQEn1fSqDmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khob-khun-thai-cuisine-and-breakfast-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 180,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78107129493808,
#     'longitude': -122.45966259993912},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3741 Geary Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3741 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '+14153794382',
#    'display_phone': '(415) 379-4382',
#    'distance': 3032.307778458133},
#   {'id': 't6TROjhvQzXJEhjI_nm08g',
#    'alias': 'lys-vietnamese-cuisine-san-francisco',
#    'name': "Ly's Vietnamese Cuisine",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VPM6NyJA218VWrP8cSflHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lys-vietnamese-cuisine-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 560,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80029, 'longitude': -122.43063},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '1779 Lombard St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1779 Lombard St', 'San Francisco, CA 94123']},
#    'phone': '+14155631927',
#    'display_phone': '(415) 563-1927',
#    'distance': 4410.7710883876225},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'alias': 'marufuku-ramen-san-francisco-5',
#    'name': 'Marufuku Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouK2VmW0SrI70jsJpTxJhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marufuku-ramen-san-francisco-5?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 4490,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.785014, 'longitude': -122.431842},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1581 Webster St',
#     'address2': 'Ste 235',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1581 Webster St',
#      'Ste 235',
#      'San Francisco, CA 94115']},
#    'phone': '+14158729786',
#    'display_phone': '(415) 872-9786',
#    'distance': 2717.1759329403035},
#   {'id': '6Pbhkpqz-4ZNS_60lHvqjA',
#    'alias': 'gao-viet-kitchen-and-bar-san-francisco',
#    'name': 'Gao Viet Kitchen & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t6tb_zTceOTVRCp6tqGZKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gao-viet-kitchen-and-bar-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 157,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.763649119559766,
#     'longitude': -122.47838713171734},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '1900 Irving St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1900 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14155928090',
#    'display_phone': '(415) 592-8090',
#    'distance': 3699.432886909486},
#   {'id': 'K24TuqugeeJVkaFkS166BA',
#    'alias': 'yuanbao-jiaozi-san-francisco-2',
#    'name': 'Yuanbao Jiaozi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qFWm_AKdUNmUvCSn7EKvuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuanbao-jiaozi-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 536,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76356, 'longitude': -122.48067},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Irving St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2110 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14157026506',
#    'display_phone': '(415) 702-6506',
#    'distance': 3905.0909265492787},
#   {'id': 'SO7w-fN6uIBUEzkakrcxoQ',
#    'alias': 'ushi-taro-ramen-san-francisco-3',
#    'name': 'Ushi Taro Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WvJPkuX4ipW7QdmOzHMbzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ushi-taro-ramen-san-francisco-3?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 478,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7625462134757,
#     'longitude': -122.466102987528},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1382 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1382 9th Ave', 'San Francisco, CA 94122']},
#    'phone': '+14157026014',
#    'display_phone': '(415) 702-6014',
#    'distance': 2613.3690556023816},
#   {'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#    'alias': 'daeho-kalbijjim-and-beef-soup-san-francisco-9',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HzzU5aVz-eUYJIPdnNGL0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-9?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1676,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78601, 'longitude': -122.42858},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1620 Post St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1620 Post St', 'San Francisco, CA 94115']},
#    'phone': '+14155631388',
#    'display_phone': '(415) 563-1388',
#    'distance': 2867.8335670207744},
#   {'id': 'w8FENzEJt0v1gPx568N0iA',
#    'alias': 'pho-huong-viet-san-francisco',
#    'name': 'Pho Huong Viet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hB5mEmd6Pn1U2UulPIvuPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-huong-viet-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 240,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.77995, 'longitude': -122.48105},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5733 Geary Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5733 Geary Blvd', 'San Francisco, CA 94121']},
#    'phone': '+14157026177',
#    'display_phone': '(415) 702-6177',
#    'distance': 4459.68149332107},
#   {'id': 'BI40rGhpngLNPacrjWpseQ',
#    'alias': 'dumpling-kitchen-san-francisco',
#    'name': 'Dumpling Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rggI1HG_kaABtAGNiuqF9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumpling-kitchen-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 2022,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7423, 'longitude': -122.48701},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1935 Taraval St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1935 Taraval St', 'San Francisco, CA 94116']},
#    'phone': '+14156828938',
#    'display_phone': '(415) 682-8938',
#    'distance': 4904.15624633216},
#   {'id': 'MsdA2LpPGwcl80w0RVQ5vg',
#    'alias': 'papas-kitchen-san-francisco',
#    'name': "Papa's Kitchen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUOPAtUH4u5ayOUR4Xw7yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papas-kitchen-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 42,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76941818035567,
#     'longitude': -122.45093920833247},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1705 Haight St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1705 Haight St', 'San Francisco, CA 94117']},
#    'phone': '+14157424040',
#    'display_phone': '(415) 742-4040',
#    'distance': 1587.4722540693626},
#   {'id': 'wCf2GGyEOkaSFE0xCYpgOA',
#    'alias': 'hai-ky-noodles-san-francisco',
#    'name': 'Hai Ky Noodles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x1FoljmTD6uPnNntyZggfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hai-ky-noodles-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1153,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7840538024902,
#     'longitude': -122.417953491211},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '707 Ellis St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['707 Ellis St', 'San Francisco, CA 94109']},
#    'phone': '+14157712577',
#    'display_phone': '(415) 771-2577',
#    'distance': 3044.718892971255},
#   {'id': 'KhG-jWIr7-TJj3isz3ZIFQ',
#    'alias': 'my-tofu-house-san-francisco',
#    'name': 'My Tofu House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vA2xV-Til4noh-f3QilugQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-tofu-house-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1723,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7806563, 'longitude': -122.4691286},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4627 Geary Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4627 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '+14157501818',
#    'display_phone': '(415) 750-1818',
#    'distance': 3616.331071494143},
#   {'id': '6L6kz5GVJqJIyM0SuWyPDQ',
#    'alias': 'yuji-san-francisco',
#    'name': 'Yuji',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VXxQ2P2YhEyp6mF7eh1uOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuji-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 32,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.7857557, 'longitude': -122.4301162},
#    'transactions': [],
#    'location': {'address1': '1700 post st',
#     'address2': 'Unit K',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1700 post st', 'Unit K', 'San Francisco, CA 94115']},
#    'phone': '+14156587128',
#    'display_phone': '(415) 658-7128',
#    'distance': 2819.349668193275},
#   {'id': 'EQpVnmoC_itgVQaaAYKNtg',
#    'alias': 'c-q-noodles-san-francisco',
#    'name': 'C.Q. Noodles ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CqMOsXM4JRyhswR4ZdckEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c-q-noodles-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 13,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78219994794561,
#     'longitude': -122.48209291576293},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2121 Clement St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2121 Clement St', 'San Francisco, CA 94121']},
#    'phone': '+14157515332',
#    'display_phone': '(415) 751-5332',
#    'distance': 4658.9974461057},
#   {'id': 'hpWcjUQ0dhXRN-2wUWQYCQ',
#    'alias': 'cinderella-bakery-and-cafe-san-francisco-2',
#    'name': 'Cinderella Bakery & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tLh1kX5-Vx1JnzJNSr98xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cinderella-bakery-and-cafe-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1278,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77745, 'longitude': -122.46374},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '436 Balboa St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['436 Balboa St', 'San Francisco, CA 94118']},
#    'phone': '+14157519690',
#    'display_phone': '(415) 751-9690',
#    'distance': 3016.7805989414596},
#   {'id': 'KCVZ0Z5GQgQxduizQ91O1Q',
#    'alias': 'yummy-yummy-san-francisco',
#    'name': 'Yummy Yummy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CEcsprYvGA8TMsxY92XtPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yummy-yummy-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1550,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76368, 'longitude': -122.46879},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1015 Irving St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1015 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14155664722',
#    'display_phone': '(415) 566-4722',
#    'distance': 2861.847455798399},
#   {'id': 'wMZTLm2HtPvPh0XoM0QhJQ',
#    'alias': 'saigon-bbq-noodle-house-san-francisco-2',
#    'name': 'Saigon BBQ Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_XYVqzOueMyJIiqHblA3zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saigon-bbq-noodle-house-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 212,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.763608739963686,
#     'longitude': -122.47890553149897},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1936 Irving St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1936 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14159417970',
#    'display_phone': '(415) 941-7970',
#    'distance': 3744.4864076435474},
#   {'id': 'wcd3le230DbZAxEp6VOBhQ',
#    'alias': 'viet-quan-vietnamese-noodle-house-san-francisco',
#    'name': 'Viet Quan Vietnamese Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/77Oob93DNhz9KO4kd4_Uqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/viet-quan-vietnamese-noodle-house-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 125,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.74244, 'longitude': -122.4851},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1757 Taraval St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1757 Taraval St', 'San Francisco, CA 94116']},
#    'phone': '+14156828200',
#    'display_phone': '(415) 682-8200',
#    'distance': 4749.068057502739},
#   {'id': 'JwbyzqL33R4oRk5-ymubYg',
#    'alias': 'jjamppong-san-francisco-4',
#    'name': 'JJamPPong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O8uY1JBsGk-ZFxCDIQ202A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jjamppong-san-francisco-4?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 338,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.71467, 'longitude': -122.4423},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5249 Mission St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94112',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5249 Mission St', 'San Francisco, CA 94112']},
#    'phone': '+14153477412',
#    'display_phone': '(415) 347-7412',
#    'distance': 5169.687116806051},
#   {'id': 'Jc5l9gRCYb6EXY7mg9BRLQ',
#    'alias': 'sunflower-garden-san-francisco',
#    'name': 'Sunflower Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FQpwoFn0AGK6jjj_W64tBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunflower-garden-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 244,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76281, 'longitude': -122.46589},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1368 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1368 9th Ave', 'San Francisco, CA 94122']},
#    'phone': '+14155718850',
#    'display_phone': '(415) 571-8850',
#    'distance': 2605.362830679326},
#   {'id': 'D1-_5ff4aic1-7rLqzUd4g',
#    'alias': 'yamo-san-francisco',
#    'name': 'Yamo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i6mg9G3LJzESSgqSnptbVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yamo-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 2093,
#    'categories': [{'alias': 'burmese', 'title': 'Burmese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7619475, 'longitude': -122.4196787},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3406 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3406 18th St', 'San Francisco, CA 94110']},
#    'phone': '+14155538911',
#    'display_phone': '(415) 553-8911',
#    'distance': 1476.7404023925897},
#   {'id': '6mimgHs5Zp92w10yy5TjzA',
#    'alias': 'tang-bar-san-francisco',
#    'name': 'Tang Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oV0YToAoSUaxWtx_AyI7Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tang-bar-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 322,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.72895084047332,
#     'longitude': -122.47682908998571},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3251 20th Ave',
#     'address2': 'Ste 218',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94132',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3251 20th Ave',
#      'Ste 218',
#      'San Francisco, CA 94132']},
#    'phone': '+16282709876',
#    'display_phone': '(628) 270-9876',
#    'distance': 5022.692627430608},
#   {'id': 'hzj5Az-SD6ZhUkKZkqGbcw',
#    'alias': 'laksa-san-francisco',
#    'name': 'Laksa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5SKppML38k5uPcnGWGlWNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laksa-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 331,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7547198093377,
#     'longitude': -122.422967755128},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1005 Guerrero St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1005 Guerrero St', 'San Francisco, CA 94110']},
#    'phone': '+14159137396',
#    'display_phone': '(415) 913-7396',
#    'distance': 1369.802882002632},
#   {'id': 'BbmiVo55an8Ps8RekommgQ',
#    'alias': 'sing-siu-zai-min-san-francisco',
#    'name': 'Sing Siu Zai Min',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cgDmvKaDomWMwRUlqn3fdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sing-siu-zai-min-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 34,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7376, 'longitude': -122.46928},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '321 W Portal Ave',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94127',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['321 W Portal Ave',
#      'Ste A',
#      'San Francisco, CA 94127']},
#    'phone': '+14155718340',
#    'display_phone': '(415) 571-8340',
#    'distance': 3878.8148889632016},
#   {'id': '0mNzmmh1mrdh5Cpg2QUBiw',
#    'alias': 'lapisara-eatery-san-francisco-2',
#    'name': 'Lapisara Eatery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KPAzk-Q-UM5YOdyVyE760A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lapisara-eatery-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1333,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7878344, 'longitude': -122.4131853},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '698 Post St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['698 Post St', 'San Francisco, CA 94109']},
#    'phone': '+14156553556',
#    'display_phone': '(415) 655-3556',
#    'distance': 3627.397813087025},
#   {'id': 'CBeM82Cl4Lxf4cmNOtGA-w',
#    'alias': 'daeho-kalbijjim-and-beef-soup-san-francisco-10',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ALzgL3wzlkYbWcDa78Vwgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daeho-kalbijjim-and-beef-soup-san-francisco-10?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 136,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.710417, 'longitude': -122.467703},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3995 Alemany Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94132',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3995 Alemany Blvd', 'San Francisco, CA 94132']},
#    'phone': '+16288950505',
#    'display_phone': '(628) 895-0505',
#    'distance': 6273.8973600670715},
#   {'id': '-Wei8JiA-RBzuSnO_9X0FQ',
#    'alias': 'rooster-and-rice-san-francisco-4',
#    'name': 'Rooster & Rice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpBunisFjuyLrLU9XUaFVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rooster-and-rice-san-francisco-4?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 504,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7979011997338,
#     'longitude': -122.436055409297},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2211 Filbert St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2211 Filbert St', 'San Francisco, CA 94123']},
#    'phone': '+14157763647',
#    'display_phone': '(415) 776-3647',
#    'distance': 4114.553018985324},
#   {'id': 'vth2jtXfVUCRJeIP680CyA',
#    'alias': 'udon-mugizo-san-francisco-11',
#    'name': 'Udon Mugizo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7M2QWfxKnGU8qCMl1edeMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/udon-mugizo-san-francisco-11?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1411,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78501, 'longitude': -122.431741},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1581 Webster St',
#     'address2': 'Ste 217',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1581 Webster St',
#      'Ste 217',
#      'San Francisco, CA 94115']},
#    'phone': '+14159313118',
#    'display_phone': '(415) 931-3118',
#    'distance': 2712.696327480518},
#   {'id': 'CaqzKTAzHfPOIFkLp7xyBQ',
#    'alias': 'mendocino-farms-san-francisco',
#    'name': 'Mendocino Farms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QU7PZZiLrZSdYYDS7Gfi0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mendocino-farms-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 287,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7927841, 'longitude': -122.4023581},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '465 California St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['465 California St', 'San Francisco, CA 94104']},
#    'phone': '+14153212170',
#    'display_phone': '(415) 321-2170',
#    'distance': 4641.790624466636},
#   {'id': '-BKIqDQ3CawzwyN9kW1-FQ',
#    'alias': 'mangrove-kitchen-san-francisco',
#    'name': 'Mangrove Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5p-s9YIaFxhZUpApYtjAcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mangrove-kitchen-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 367,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77251, 'longitude': -122.43696},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '312 Divisadero St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['312 Divisadero St', 'San Francisco, CA 94117']},
#    'phone': '+14155526881',
#    'display_phone': '(415) 552-6881',
#    'distance': 1292.4569284214758},
#   {'id': '1IqqA8pcuCIWJtuKfHwU8g',
#    'alias': 'nojo-ramen-tavern-san-francisco-6',
#    'name': 'Nojo Ramen Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f8jcPmO2OhZr9w11Bj2zeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nojo-ramen-tavern-san-francisco-6?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 1162,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77669, 'longitude': -122.42151},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['231 Franklin St', 'San Francisco, CA 94102']},
#    'phone': '+14158964587',
#    'display_phone': '(415) 896-4587',
#    'distance': 2195.1792248237157},
#   {'id': 'ATj-8RmOJln9UnCEuraEzw',
#    'alias': 'noodle-in-a-haystack-san-francisco',
#    'name': 'Noodle in a Haystack',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BoEM-6j0592nJhFGHMu-jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-in-a-haystack-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 62,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.78066412799114,
#     'longitude': -122.46872181182351},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '4601 Geary Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4601 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3588.5283928892763},
#   {'id': 'I0qXHSJwUR0Xj8H91ovBPA',
#    'alias': 'my-fathers-kitchen-san-francisco',
#    'name': "My Father's Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fN4vk4jKNI0wmn7bO2E4hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-fathers-kitchen-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 513,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 37.78503492994844,
#     'longitude': -122.44000719877698},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1655 Divisadero St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1655 Divisadero St', 'San Francisco, CA 94115']},
#    'phone': '+14158292610',
#    'display_phone': '(415) 829-2610',
#    'distance': 2701.9262632232917},
#   {'id': '4jqo3BvBEiNrvLKJW41Qbg',
#    'alias': 'the-public-izakaya-san-francisco',
#    'name': 'The Public Izakaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0Z6wEKb0VOu96RLE7sCTHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-public-izakaya-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 218,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.787836462530876, 'longitude': -122.413599},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '700 Post St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['700 Post St', 'San Francisco, CA 94109']},
#    'phone': '+14156587588',
#    'display_phone': '(415) 658-7588',
#    'distance': 3606.1481462817164}],
#  'total': 4500,
#  'region': {'center': {'longitude': -122.43644714355469,
#    'latitude': 37.76089938976322}}}

# %%
url
# Out:
# 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# **get business info**

# %%
url = os.path.join(url_base, url_business)
api_header = {'Authorization': apikey, 'accept': 'application/json'}

for offset in range(0, 50, 50):
    params = {
        'location': 'San Francisco',
        'term': '{restaurants}',
        'limit': 50,
        'offset': offset
    }

    r = requests.get(url, headers=api_header, params=params)
    
    result = json.loads(r.text)
    busi_list = result['businesses']
    busi_df = pd.DataFrame(columns=['id', 'name', 'rating', 'url', 'review_cnt'])
    for i in range(len(busi_list)):
        busi_df.loc[i, 'id'] = busi_list[i]['id']
        busi_df.loc[i, 'name'] = busi_list[i]['name']
        busi_df.loc[i, 'rating'] = busi_list[i]['rating']
        busi_df.loc[i, 'url'] = busi_list[i]['url'].split('?')[0]
        busi_df.loc[i, 'review_cnt'] = busi_list[i]['review_count']
    
    result = pd.DataFrame(columns=['id', 'name', 'rating', 'review', 'total_review'])
    idx = 0
    error_count = 0 
    for res in range(len(busi_df)):
        new_page = "?start={}"
        base_url = busi_df.loc[res, 'url']
        cnt = busi_df.loc[res, 'review_cnt']

        # soup = BeautifulSoup(content, "html.parser")
        sleep(2)
        for i in range(0, min(cnt, 100), 10):
            new_page_url = base_url + new_page.format(i)
            try: 
                new_content = requests.get(new_page_url).content
            except Exception as e:
                with open('logs.txt','w') as f:
                    timestamp = str(datetime.now())
                    error_string = f'{timestamp} : Error while using request. Error output {e} \n'
                    f.write(error_string)
                    error_count += 1

            try:

                new_soup = BeautifulSoup(new_content, "html.parser")

                relevant= new_soup.find_all('p', class_='comment__09f24__gu0rG css-qgunke')
                for div in relevant:
                    for html_class in div.find_all('span',class_="raw__09f24__T4Ezm"):
                        text = html_class.find('span')
                        review = html_class.getText()
                        result.loc[idx, 'id'] = busi_df.loc[res, 'id']
                        result.loc[idx, 'name'] = busi_df.loc[res, 'name']
                        result.loc[idx, 'rating'] = busi_df.loc[res, 'rating']
                        result.loc[idx, 'total_review'] = busi_df.loc[res, 'review_cnt']
                        result.loc[idx, 'review'] = review

                        idx += 1
            except Exception as e:
                with open('logs.txt','w') as f:
                    timestamp = str(datetime.now())
                    error_string = f'{timestamp} : Error while parsing with BeautifulSoup. Error output {e} \n'
                    f.write(error_string)
                    error_count += 1

            if error_count > 10:
                break
            
    outfile = str(offset)+'_review_result.csv'
    result.to_csv(outfile)

# %%
result = json.loads(r.text)
len(result['businesses'])
# Out:
# 50

# %%
busi_list = result['businesses']
busi_list[0]
# Out:
# {'id': 'oa6ZaLdQNzZHP7--gxBh2g',
#  'alias': 'california-fish-market-restaurant-san-francisco-3',
#  'name': 'California Fish Market Restaurant',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dT8Dx6y0ElNeU5Xe3funCQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/california-fish-market-restaurant-san-francisco-3?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#  'review_count': 521,
#  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#   {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#   {'alias': 'italian', 'title': 'Italian'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 37.7998, 'longitude': -122.40832},
#  'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '550 Green St',
#   'address2': '',
#   'address3': None,
#   'city': 'San Francisco',
#   'zip_code': '94133',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['550 Green St', 'San Francisco, CA 94133']},
#  'phone': '+14157570918',
#  'display_phone': '(415) 757-0918',
#  'distance': 4983.514370435519}

# %%
busi_df = pd.DataFrame(columns=['id', 'name', 'rating', 'url', 'review_cnt'])
for i in range(len(busi_list)):
    busi_df.loc[i, 'id'] = busi_list[i]['id']
    busi_df.loc[i, 'name'] = busi_list[i]['name']
    busi_df.loc[i, 'rating'] = busi_list[i]['rating']
    busi_df.loc[i, 'url'] = busi_list[i]['url'].split('?')[0]
    busi_df.loc[i, 'review_cnt'] = busi_list[i]['review_count']

# %%
busi_df
# Out:
#                         id                            name rating  \
# 0   s2R3RUJ09eBFvHVIUS4Shg                 Kothai Republic    5.0
# 1   6YuJE0vjUpIzYckRMnzy0g                           Savor    5.0
# 2   J7_-faNq_Ag9qTOlDn81Pw                       Starbelly    4.0
# 3   SUdC4LIL3huirbbBkHrhfw                  The Laundromat    4.5
# 4   HHtpR0RslupSQ99GIIwW5A                  Marufuku Ramen    4.5
# 5   QueFVMcMlT-6aZFv2M47mg                         Bottega    4.5
# 6   f-m7-hyFzkf0HSEeQ2s-9A           Fog Harbor Fish House    4.5
# 7   AtFGQccBpgEZzsy9V1330Q                            Lily    4.5
# 8   d5752S_RDb26HxoL6O06eQ                       Beit Rima    4.5
# 9   _hOVIgjVRl_HzvLaa65KJg                        The Snug    4.0
# 10  8VurRDEj1RpimenhgTmyFQ                   KAIYŌ Rooftop    4.0
# 11  XAYwAF_83becwNnSJDFkpA                  Dumpling House    4.5
# 12  LPoRD0huneBqPZbg1wsJ_Q                   Jamie's Place    4.5
# 13  8dUaybEPHsZMgr1iKgqgMQ                      Sotto Mare    4.5
# 14  6Pbhkpqz-4ZNS_60lHvqjA          Gao Viet Kitchen & Bar    4.5
# 15  2E9O-p-lp587aOMnpLepkQ                          JIJIME    4.5
# 16  OOlS_RmdMk1LHtgOQWoHoA                         Tanglad    4.5
# 17  D26qBnudK_1pdo6AlvMlvQ                            Otra    4.5
# 18  E2Ri3Uudb3ogKfWBJIIhRw                           Lokma    4.5
# 19  8u7pyRsCdf0DOP-Vg6MuLQ                     Purple Rice    4.5
# 20  qfRZjzNqO3fRgEGqvGNY-A                        Santeria    4.5
# 21  MaaySW1ejpwQCkr9jn1glA                The Tailor's Son    4.0
# 22  9Z9EETl8fZIP4s9KOHr5kg                           Um Ma    4.0
# 23  q7PEtlrwVwHrQv0M6Mzwvw                Dumpling Kitchen    4.5
# 24  wAwwPDRiO2qYsk7VgcNi_Q                   That's My Jam    5.0
# 25  L0Kanq9vtkYaId7dguEOsQ                         Automat    4.0
# 26  ttarnopezxmp2ROB1N2PaA                            Nopa    4.0
# 27  sfqkkqFmmYGOT0PCbbD9ZQ                           Pearl    4.5
# 28  UYNswbdsQ5OvwnyY9esxCw                    Wooden Spoon    4.5
# 29  TA0u_BzRvFKX2T8ujW6ozA               Hu Tong Jian Bing    4.0
# 30  2hGIxgprREdBieylltWaRQ                      Limoncello    5.0
# 31  -DrR38H1Abk0wCyu9XOLug                     Sweet Maple    4.5
# 32  E_W8aGdYm8hnfy1WuGJcVQ                     Pinsa Rossa    4.5
# 33  FRpULkKmvD9caSKabQzq5w    The Italian Homemade Company    4.5
# 34  lUUQi1b2rV3glIn4t2I1Iw                    Horsefeather    4.0
# 35  dY0Mc_PHH6nLENvWmVtwxQ     Daeho Kalbijjim & Beef Soup    4.5
# 36  ATj-8RmOJln9UnCEuraEzw            Noodle in a Haystack    5.0
# 37  w3mpnxz64nU8VwHDLz3S6g                      Breadbelly    4.5
# 38  M0JTO3oyu6gxh1mfFjU-dA                        San Tung    4.0
# 39  BI40rGhpngLNPacrjWpseQ                Dumpling Kitchen    4.0
# 40  kvrQecqdGvnuVICMstZJmA                   Dumpling Home    4.5
# 41  ebxKpS__p4zuGM-kAHDbMw                           Arang    4.5
# 42  reXWH9Wo0ZTOuQsTMNOSxg                           Fable    4.0
# 43  x2djtavZIsv84ZKnz_vRMA                         Beretta    4.0
# 44  IlkvuSkI1LF5y-Q3jpWrWQ                    Cafe De Casa    4.5
# 45  8kck3-K4zYKTJbJko0JlXQ  Farmhouse Kitchen Thai Cuisine    4.0
# 46  jU7vhPz-vUmjMlxMf9cTXA                          Alnico    4.0
# 47  cCVR9W_L2rqexfKAjfBTzQ                         Routier    4.5
# 48  9AeBzGI0OOXfM4StDpwwGQ                   Rise Over Run    4.5
# 49  LsGkxQK217twdzZzVXsSRg                          CreoLa    4.5
#
#                                                   url review_cnt
# 0   https://www.yelp.com/biz/kothai-republic-san-f...         37
# 1      https://www.yelp.com/biz/savor-san-francisco-7         88
# 2    https://www.yelp.com/biz/starbelly-san-francisco       2166
# 3   https://www.yelp.com/biz/the-laundromat-san-fr...         55
# 4   https://www.yelp.com/biz/marufuku-ramen-san-fr...       4355
# 5    https://www.yelp.com/biz/bottega-san-francisco-2        541
# 6   https://www.yelp.com/biz/fog-harbor-fish-house...       8810
# 7         https://www.yelp.com/biz/lily-san-francisco        308
# 8   https://www.yelp.com/biz/beit-rima-san-francis...        219
# 9     https://www.yelp.com/biz/the-snug-san-francisco        366
# 10  https://www.yelp.com/biz/kaiy%C5%8D-rooftop-sa...        432
# 11  https://www.yelp.com/biz/dumpling-house-san-fr...        404
# 12  https://www.yelp.com/biz/jamies-place-san-fran...        269
# 13  https://www.yelp.com/biz/sotto-mare-san-franci...       4755
# 14  https://www.yelp.com/biz/gao-viet-kitchen-and-...         78
# 15    https://www.yelp.com/biz/jijime-san-francisco-8        527
# 16     https://www.yelp.com/biz/tanglad-san-francisco        226
# 17      https://www.yelp.com/biz/otra-san-francisco-3        124
# 18       https://www.yelp.com/biz/lokma-san-francisco        591
# 19  https://www.yelp.com/biz/purple-rice-san-franc...        238
# 20    https://www.yelp.com/biz/santeria-san-francisco        251
# 21  https://www.yelp.com/biz/the-tailors-son-san-f...        365
# 22     https://www.yelp.com/biz/um-ma-san-francisco-3        616
# 23  https://www.yelp.com/biz/dumpling-kitchen-san-...         58
# 24  https://www.yelp.com/biz/thats-my-jam-san-fran...         42
# 25   https://www.yelp.com/biz/automat-san-francisco-2        189
# 26        https://www.yelp.com/biz/nopa-san-francisco       5350
# 27     https://www.yelp.com/biz/pearl-san-francisco-8        403
# 28  https://www.yelp.com/biz/wooden-spoon-san-fran...        576
# 29  https://www.yelp.com/biz/hu-tong-jian-bing-san...         36
# 30  https://www.yelp.com/biz/limoncello-san-francisco       1565
# 31  https://www.yelp.com/biz/sweet-maple-san-franc...       4530
# 32  https://www.yelp.com/biz/pinsa-rossa-san-franc...         28
# 33  https://www.yelp.com/biz/the-italian-homemade-...       1146
# 34  https://www.yelp.com/biz/horsefeather-san-fran...        482
# 35  https://www.yelp.com/biz/daeho-kalbijjim-and-b...       1604
# 36  https://www.yelp.com/biz/noodle-in-a-haystack-...         60
# 37  https://www.yelp.com/biz/breadbelly-san-francisco        440
# 38  https://www.yelp.com/biz/san-tung-san-francisco-2       7842
# 39  https://www.yelp.com/biz/dumpling-kitchen-san-...       1995
# 40  https://www.yelp.com/biz/dumpling-home-san-fra...        809
# 41       https://www.yelp.com/biz/arang-san-francisco         25
# 42       https://www.yelp.com/biz/fable-san-francisco        759
# 43   https://www.yelp.com/biz/beretta-san-francisco-2        356
# 44  https://www.yelp.com/biz/cafe-de-casa-san-fran...        136
# 45  https://www.yelp.com/biz/farmhouse-kitchen-tha...       3486
# 46      https://www.yelp.com/biz/alnico-san-francisco        510
# 47     https://www.yelp.com/biz/routier-san-francisco        123
# 48  https://www.yelp.com/biz/rise-over-run-san-fra...         21
# 49    https://www.yelp.com/biz/creola-san-francisco-3        161

# %%
result = pd.DataFrame(columns=['id', 'name', 'rating', 'review', 'total_review'])
idx = 0
error_count = 0 
for res in range(len(busi_df)):
    new_page = "?start={}"
    base_url = busi_df.loc[res, 'url']
    cnt = busi_df.loc[res, 'review_cnt']

    # soup = BeautifulSoup(content, "html.parser")
    sleep(2)
    for i in range(0, min(cnt, 100), 10):
        new_page_url = base_url + new_page.format(i)
        try: 
            new_content = requests.get(new_page_url).content
        except Exception as e:
            with open('logs.txt','w') as f:
                timestamp = str(datetime.now())
                error_string = f'{timestamp} : Error while using request. Error output {e} \n'
                f.write(error_string)
                error_count += 1
        
        try:
            
            new_soup = BeautifulSoup(new_content, "html.parser")

            relevant= new_soup.find_all('p', class_='comment__09f24__gu0rG css-qgunke')
            for div in relevant:
                for html_class in div.find_all('span',class_="raw__09f24__T4Ezm"):
                    text = html_class.find('span')
                    review = html_class.getText()
                    result.loc[idx, 'id'] = busi_df.loc[res, 'id']
                    result.loc[idx, 'name'] = busi_df.loc[res, 'name']
                    result.loc[idx, 'rating'] = busi_df.loc[res, 'rating']
                    result.loc[idx, 'total_review'] = busi_df.loc[res, 'review_cnt']
                    result.loc[idx, 'review'] = review

                    idx += 1
        except Exception as e:
            with open('logs.txt','w') as f:
                timestamp = str(datetime.now())
                error_string = f'{timestamp} : Error while parsing with BeautifulSoup. Error output {e} \n'
                f.write(error_string)
                error_count += 1
                
        if error_count > 10:
            break

# %%
result.to_csv('50_review_result.csv')

# %%
result
# Out:
#                           id             name rating  \
# 0     s2R3RUJ09eBFvHVIUS4Shg  Kothai Republic    5.0
# 1     s2R3RUJ09eBFvHVIUS4Shg  Kothai Republic    5.0
# 2     s2R3RUJ09eBFvHVIUS4Shg  Kothai Republic    5.0
# 3     s2R3RUJ09eBFvHVIUS4Shg  Kothai Republic    5.0
# 4     s2R3RUJ09eBFvHVIUS4Shg  Kothai Republic    5.0
# ...                      ...              ...    ...
# 4413  LsGkxQK217twdzZzVXsSRg           CreoLa    4.5
# 4414  LsGkxQK217twdzZzVXsSRg           CreoLa    4.5
# 4415  LsGkxQK217twdzZzVXsSRg           CreoLa    4.5
# 4416  LsGkxQK217twdzZzVXsSRg           CreoLa    4.5
# 4417  LsGkxQK217twdzZzVXsSRg           CreoLa    4.5
#
#                                                  review total_review
# 0     KOREAN-THAI, KOTHAI! It has a nice ring to it....           37
# 1     I heard about this Thai/Korean fusion restaura...           37
# 2     Great dishes and execution. I loved the Tom Yu...           37
# 3     Kothai Republic has so much potential and I ca...           37
# 4     Food truck turned brick and mortar. Still defi...           37
# ...                                                 ...          ...
# 4413  So excited for a new restaurant in the neighbo...          161
# 4414  We had food from here twice - Once our friends...          161
# 4415  I used to live in San Francisco and was deligh...          161
# 4416  Their fried chicken is full of flavor, and cri...          161
# 4417  I love this place! I got Seafood Gumbo and I l...          161
#
# [4418 rows x 5 columns]

# %%
import pandas as pd
import os

# %%
filelists = os.listdir('data')
# result = pd.DataFrame()
# for f in filelists:
#     tmp = pd.read_csv('data/'+f)

# %%
result = pd.concat([pd.read_csv('data/'+f) for f in filelists ])

# %%
result.to_csv('data.csv')
