# %%
import os
import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
from time import sleep

from datetime import datetime

# %%
url_base = 'https://api.yelp.com/v3/'

url_review = 'businesses/{id}/reviews'
url_business = 'businesses/search'

apikey = 'Bearer CrgilvjOJW-U-DnMiyFz_xypRqtVtfL_yekfgb4Kg5xNRWe1A83s2llrJ7RxnXYa0iqT8GwTCHJZKvYMHL7CmV1zJPe0D1_jWrH8W0bMxTtR6Ufksbg5REDVrSDbY3Yx'

# %% [markdown]
# **get business info**

# %%
url = os.path.join(url_base, url_business)
api_header = {'Authorization': apikey, 'accept': 'application/json'}

params = {
    'location': 'San Francisco',
    'term': 'restaurants',
    'limit': 10,
}

r = requests.get(url, headers=api_header, params=params)

# %%
result = json.loads(r.text)
result
# Out:
# {'businesses': [{'id': 's2R3RUJ09eBFvHVIUS4Shg',
#    'alias': 'kothai-republic-san-francisco',
#    'name': 'Kothai Republic',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9zVMgsspT6yDf1fUevHewQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kothai-republic-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 34,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.76219, 'longitude': -122.46604},
#    'transactions': [],
#    'location': {'address1': '1398 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1398 9th Ave', 'San Francisco, CA 94122']},
#    'phone': '+14157424058',
#    'display_phone': '(415) 742-4058',
#    'distance': 2606.5969287543485},
#   {'id': '6Pbhkpqz-4ZNS_60lHvqjA',
#    'alias': 'gao-viet-kitchen-and-bar-san-francisco',
#    'name': 'Gao Viet Kitchen & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oZLkhjS0imz_Pdn4_hUDuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gao-viet-kitchen-and-bar-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 76,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.763649119559766,
#     'longitude': -122.47838713171734},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '1900 Irving St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1900 Irving St', 'San Francisco, CA 94122']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3699.432886909486},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'alias': 'marufuku-ramen-san-francisco-5',
#    'name': 'Marufuku Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouK2VmW0SrI70jsJpTxJhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marufuku-ramen-san-francisco-5?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 4349,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.785014, 'longitude': -122.431842},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1581 Webster St',
#     'address2': 'Ste 235',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1581 Webster St',
#      'Ste 235',
#      'San Francisco, CA 94115']},
#    'phone': '+14158729786',
#    'display_phone': '(415) 872-9786',
#    'distance': 2717.1759329403035},
#   {'id': 'QueFVMcMlT-6aZFv2M47mg',
#    'alias': 'bottega-san-francisco-2',
#    'name': 'Bottega',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IawDcF1QmHSzUQDczHYVuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bottega-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 540,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.75472, 'longitude': -122.4212},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1132 Valencia St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1132 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14156559048',
#    'display_phone': '(415) 655-9048',
#    'distance': 1506.2503434999724},
#   {'id': 'J7_-faNq_Ag9qTOlDn81Pw',
#    'alias': 'starbelly-san-francisco',
#    'name': 'Starbelly',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G1SweY3VbKx_BqAws9RytA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/starbelly-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 2166,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76402, 'longitude': -122.43253},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3583 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3583 16th St', 'San Francisco, CA 94114']},
#    'phone': '+14152527500',
#    'display_phone': '(415) 252-7500',
#    'distance': 490.0201155034338},
#   {'id': 'AtFGQccBpgEZzsy9V1330Q',
#    'alias': 'lily-san-francisco',
#    'name': 'Lily',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y80_nZ_LfLw5AZip8L-MEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lily-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 307,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.782826, 'longitude': -122.461686},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '225 Clement St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['225 Clement St', 'San Francisco, CA 94118']},
#    'phone': '+14157425285',
#    'display_phone': '(415) 742-5285',
#    'distance': 3299.107317666393},
#   {'id': '_hOVIgjVRl_HzvLaa65KJg',
#    'alias': 'the-snug-san-francisco',
#    'name': 'The Snug',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MutHRQoBt5krVldjIK88IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-snug-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 365,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.79094, 'longitude': -122.43443},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2301 Fillmore St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2301 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3342.887795851584},
#   {'id': '8VurRDEj1RpimenhgTmyFQ',
#    'alias': 'kaiyō-rooftop-san-francisco-5',
#    'name': 'KAIYŌ Rooftop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IpnkGDpsm94wGzTAdFekPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaiy%C5%8D-rooftop-san-francisco-5?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 431,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77882, 'longitude': -122.3924},
#    'transactions': [],
#    'location': {'address1': '701 3rd St',
#     'address2': 'Fl 12',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94105',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['701 3rd St', 'Fl 12', 'San Francisco, CA 94105']},
#    'phone': '+14158008141',
#    'display_phone': '(415) 800-8141',
#    'distance': 4355.096615628698},
#   {'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'alias': 'fog-harbor-fish-house-san-francisco-2',
#    'name': 'Fog Harbor Fish House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/by8Hh63BLPv_HUqRUdsp_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 8811,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80898821475503,
#     'longitude': -122.41029651587517},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '39 Pier',
#     'address2': 'Ste a - 202',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['39 Pier', 'Ste a - 202', 'San Francisco, CA 94133']},
#    'phone': '+14159692010',
#    'display_phone': '(415) 969-2010',
#    'distance': 5820.143221179387},
#   {'id': 'XAYwAF_83becwNnSJDFkpA',
#    'alias': 'dumpling-house-san-francisco',
#    'name': 'Dumpling House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DNfqq1zYxbJ-gsalml7wng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumpling-house-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#    'review_count': 404,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.763552, 'longitude': -122.432762},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '335 Noe St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['335 Noe St', 'San Francisco, CA 94114']},
#    'phone': '+14158292789',
#    'display_phone': '(415) 829-2789',
#    'distance': 436.04221561234874}],
#  'total': 5100,
#  'region': {'center': {'longitude': -122.43644714355469,
#    'latitude': 37.76089938976322}}}

# %%
busi_list = result['businesses']
busi_list[0]
# Out:
# {'id': 's2R3RUJ09eBFvHVIUS4Shg',
#  'alias': 'kothai-republic-san-francisco',
#  'name': 'Kothai Republic',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9zVMgsspT6yDf1fUevHewQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/kothai-republic-san-francisco?adjust_creative=bpQq5NcAeZPqAmDOGLjWgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bpQq5NcAeZPqAmDOGLjWgA',
#  'review_count': 34,
#  'categories': [{'alias': 'korean', 'title': 'Korean'},
#   {'alias': 'thai', 'title': 'Thai'}],
#  'rating': 5.0,
#  'coordinates': {'latitude': 37.76219, 'longitude': -122.46604},
#  'transactions': [],
#  'location': {'address1': '1398 9th Ave',
#   'address2': None,
#   'address3': '',
#   'city': 'San Francisco',
#   'zip_code': '94122',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['1398 9th Ave', 'San Francisco, CA 94122']},
#  'phone': '+14157424058',
#  'display_phone': '(415) 742-4058',
#  'distance': 2606.5969287543485}

# %%
busi_df = pd.DataFrame(columns=['id', 'name', 'rating', 'url', 'review_cnt'])
for i in range(len(busi_list)):
    busi_df.loc[i, 'id'] = busi_list[i]['id']
    busi_df.loc[i, 'name'] = busi_list[i]['name']
    busi_df.loc[i, 'rating'] = busi_list[i]['rating']
    busi_df.loc[i, 'url'] = busi_list[i]['url'].split('?')[0]
    busi_df.loc[i, 'review_cnt'] = busi_list[i]['review_count']

# %%
busi_df
# Out:
#                        id                    name rating  \
# 0  s2R3RUJ09eBFvHVIUS4Shg         Kothai Republic    5.0
# 1  6Pbhkpqz-4ZNS_60lHvqjA  Gao Viet Kitchen & Bar    4.5
# 2  HHtpR0RslupSQ99GIIwW5A          Marufuku Ramen    4.5
# 3  QueFVMcMlT-6aZFv2M47mg                 Bottega    4.5
# 4  J7_-faNq_Ag9qTOlDn81Pw               Starbelly    4.0
# 5  AtFGQccBpgEZzsy9V1330Q                    Lily    4.5
# 6  _hOVIgjVRl_HzvLaa65KJg                The Snug    4.0
# 7  8VurRDEj1RpimenhgTmyFQ           KAIYŌ Rooftop    4.0
# 8  f-m7-hyFzkf0HSEeQ2s-9A   Fog Harbor Fish House    4.5
# 9  XAYwAF_83becwNnSJDFkpA          Dumpling House    4.5
#
#                                                  url review_cnt
# 0  https://www.yelp.com/biz/kothai-republic-san-f...         34
# 1  https://www.yelp.com/biz/gao-viet-kitchen-and-...         76
# 2  https://www.yelp.com/biz/marufuku-ramen-san-fr...       4349
# 3   https://www.yelp.com/biz/bottega-san-francisco-2        540
# 4   https://www.yelp.com/biz/starbelly-san-francisco       2166
# 5        https://www.yelp.com/biz/lily-san-francisco        307
# 6    https://www.yelp.com/biz/the-snug-san-francisco        365
# 7  https://www.yelp.com/biz/kaiy%C5%8D-rooftop-sa...        431
# 8  https://www.yelp.com/biz/fog-harbor-fish-house...       8811
# 9  https://www.yelp.com/biz/dumpling-house-san-fr...        404

# %%
result = pd.DataFrame(columns=['id', 'name', 'rating', 'review', 'total_review'])
idx = 0
error_count = 0 
for res in range(len(busi_df)):
    new_page = "?start={}"
    base_url = busi_df.loc[res, 'url']
    cnt = busi_df.loc[res, 'review_cnt']

    # soup = BeautifulSoup(content, "html.parser")

    for i in range(0, min(cnt, 100), 10):
        new_page_url = base_url + new_page.format(i)
        try: 
            new_content = requests.get(new_page_url).content
        except Exception as e:
            with open('logs.txt','w') as f:
                timestamp = str(datetime.now())
                error_string = f'{timestamp} : Error while using request. Error output {e} \n'
                f.write(error_string)
                error_count += 1
        
        try:
            
            new_soup = BeautifulSoup(new_content, "html.parser")

            relevant= new_soup.find_all('p', class_='comment__09f24__gu0rG css-qgunke')
            for div in relevant:
                for html_class in div.find_all('span',class_="raw__09f24__T4Ezm"):
                    text = html_class.find('span')
                    review = html_class.getText()
                    result.loc[idx, 'id'] = busi_df.loc[res, 'id']
                    result.loc[idx, 'name'] = busi_df.loc[res, 'name']
                    result.loc[idx, 'rating'] = busi_df.loc[res, 'rating']
                    result.loc[idx, 'total_review'] = busi_df.loc[res, 'review_cnt']
                    result.loc[idx, 'review'] = review

                    idx += 1
        except Exception as e:
            with open('logs.txt','w') as f:
                timestamp = str(datetime.now())
                error_string = f'{timestamp} : Error while parsing with BeautifulSoup. Error output {e} \n'
                f.write(error_string)
                error_count += 1
                
        if error_count > 10:
            break

# %%
result.to_csv('sample_review_result.csv')

# %%
# Out:
# '2023-02-02 10:36:09.968978'
